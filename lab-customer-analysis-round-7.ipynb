# %%
import pandas as pd
file= pd.read_csv("C://Users/hugoa/Ironhack/Week_1/Day_2/lab-customer-analysis-round2/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv")
file.drop("Unnamed: 0", axis=1, inplace=True)

# %%
#1.Show the dataframe shape.


file.shape
# Out:
# (10910, 25)

# %%
file.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
#2. Standardize header
cols = []
for col in file.columns:
        cols.append(col.lower().replace(' ', '_'))
file.columns = cols

    

  
file.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
#3.Which columns are numerical?
file.select_dtypes(include=["integer", "float"])
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
#4. Which columns are categorical?
file.select_dtypes(include=["object"])
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %%
#5. Check and deal with NaN values
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10279 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10279 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %%
nulls_df = pd.DataFrame(round(file.isna().sum()/len(file),4)*100)
#display(nulls_df)
nulls_df = nulls_df.reset_index()

nulls_df.columns = ['header_name', 'percent_nulls']
display(nulls_df)

#I am displaying the variables with a percentage of nulls higher than 0
nulls_df.loc[(nulls_df['percent_nulls'] >0)]
# Out:
#                       header_name  percent_nulls
# 0                        customer           0.00
# 1                           state           5.78
# 2         customer_lifetime_value           0.00
# 3                        response           5.78
# 4                        coverage           0.00
# 5                       education           0.00
# 6               effective_to_date           0.00
# 7                employmentstatus           0.00
# 8                          gender           0.00
# 9                          income           0.00
# 10                  location_code           0.00
# 11                 marital_status           0.00
# 12           monthly_premium_auto           0.00
# 13        months_since_last_claim           5.80
# 14  months_since_policy_inception           0.00
# 15      number_of_open_complaints           5.80
# 16             number_of_policies           0.00
# 17                    policy_type           0.00
# ...

# %%
file.state.value_counts(dropna=False)
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: state, dtype: int64

# %%
#I will choose to drop all rows containing missing values since it only amounts for a 5.8%, with the exception of vehicle_type
#which I will process differently
filtered=file.dropna(subset=['state', 'response', "months_since_last_claim", "number_of_open_complaints", "vehicle_class", "vehicle_size"])

# %%
#VEHICLE TYPE
file.vehicle_type.value_counts(dropna=False)
file["vehicle_type"].unique()
# Out:
# array([nan, 'A'], dtype=object)

# %%
#There is just one correctly defined vehicle type, A. We will assign the remaining to vehicle type B, we would lose too many
#observations if we dropped all those rows.
filtered['vehicle_type'] = filtered['vehicle_type'].fillna('B').copy()
filtered.vehicle_type.value_counts(dropna=False)
# Out:
# C:\Users\hugoa\AppData\Local\Temp\ipykernel_19612\2798985971.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['vehicle_type'] = filtered['vehicle_type'].fillna('B').copy()
# B    4591
# A    4543
# Name: vehicle_type, dtype: int64

# %%
#Checking for remaining missing values
nulls_df = pd.DataFrame(round(filtered.isna().sum()/len(filtered),4)*100)
#display(nulls_df)
nulls_df = nulls_df.reset_index()

nulls_df.columns = ['header_name', 'percent_nulls']
display(nulls_df)
nulls_df.loc[(nulls_df['percent_nulls'] >0)]
# Out:
#                       header_name  percent_nulls
# 0                        customer            0.0
# 1                           state            0.0
# 2         customer_lifetime_value            0.0
# 3                        response            0.0
# 4                        coverage            0.0
# 5                       education            0.0
# 6               effective_to_date            0.0
# 7                employmentstatus            0.0
# 8                          gender            0.0
# 9                          income            0.0
# 10                  location_code            0.0
# 11                 marital_status            0.0
# 12           monthly_premium_auto            0.0
# 13        months_since_last_claim            0.0
# 14  months_since_policy_inception            0.0
# 15      number_of_open_complaints            0.0
# 16             number_of_policies            0.0
# 17                    policy_type            0.0
# ...

# %%
# 6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only 
#the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, 
#consider only January and February.

#Firstly we adapt the data from effective_to_date into datetime format  
filtered['effective_to_date'] = pd.to_datetime(filtered['effective_to_date'], errors='coerce') 
filtered.dtypes
display(filtered.head())
# Out:
# C:\Users\hugoa\AppData\Local\Temp\ipykernel_19612\2195232144.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['effective_to_date'] = pd.to_datetime(filtered['effective_to_date'], errors='coerce')
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 6  IW72280  California              5035.035257       No     Basic    Doctor
#
# ...

# %%
#Then I create a column containing the months
filtered['month'] = pd.DatetimeIndex(filtered['effective_to_date']).month
display(filtered.head())
# Out:
# C:\Users\hugoa\AppData\Local\Temp\ipykernel_19612\3275518029.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['month'] = pd.DatetimeIndex(filtered['effective_to_date']).month
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 6  IW72280  California              5035.035257       No     Basic    Doctor
#
# ...

# %%
#I filter the months
filtered[filtered.month.isin([1, 2,3])]
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %%
filtered[filtered.month.isin([3])]
#There are no observations for March
# Out:
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, response, coverage, education, effective_to_date, employmentstatus, gender, income, location_code, marital_status, monthly_premium_auto, months_since_last_claim, months_since_policy_inception, number_of_open_complaints, number_of_policies, policy_type, policy, renew_offer_type, sales_channel, total_claim_amount, vehicle_class, vehicle_size, vehicle_type, month]
# Index: []
#
# [0 rows x 26 columns]

# %%
# BONUS: Put all the previously mentioned data transformations into a function

# %%
# Customer Analysis Round 3
filtered.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 6  IW72280  California              5035.035257       No     Basic    Doctor
#
#   effective_to_date employmentstatus gender  income  ... number_of_policies  \
# 0        2011-02-18         Employed      M   48029  ...                  9
# 1        2011-01-18       Unemployed      F       0  ...                  1
# 2        2011-02-10         Employed      M   22139  ...                  2
# 3        2011-01-11         Employed      M   49078  ...                  2
# 6        2011-02-14         Employed      F   37405  ...                  4
#
# ...

# %%
#Show DataFrame info
filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 10908
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   datetime64[ns]
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
# ...

# %%
#Describe DataFrame.
filtered.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
# Show a plot of the total number of responses
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.catplot(data=filtered, x="response", kind="count")

# %%
#Show a plot of the response rate by the sales channel
#Firstly, I createa proportion tale for the different sales channels
cross_tab_prop = pd.crosstab(index=filtered['sales_channel'],
                             columns=filtered['response'],
                             normalize="index")
display(cross_tab_prop)

cross_tab_prop.plot(kind='bar', 
                    stacked=True, 
                    colormap='tab10', 
                    figsize=(10, 6))

plt.legend(loc="upper left")
plt.xlabel("Sales Channel")
plt.ylabel("Proportion")
plt.show()
# Out:
# response             No       Yes
# sales_channel
# Agent          0.808456  0.191544
# Branch         0.885469  0.114531
# Call Center    0.891218  0.108782
# Web            0.882264  0.117736

# %%
#Show a plot of the response rate by the total claim amount
ax=sns.boxplot(x="total_claim_amount", y="response", data=filtered)
ax.set(xlabel="Total Claim Amount")
ax.set(xlabel="Response")
plt.show()

# %%
#Show a plot of the response rate by income
ax=sns.boxplot(x="income", y="response", data=filtered)
ax.set(xlabel="Income")
ax.set(ylabel="Response")
plt.show()

# %%
# Check the data types of the columns. Get the numeric data into dataframe called numerical and categorical columns in 
# a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types 
#and categorical data types respectively)
numerics = ['integer', 'float']

numerical = filtered.select_dtypes(include=numerics).copy()

#It is arguable that month is actually a categorical variable, so I drop it

numerical =  numerical.drop(["month"],axis=1)
numerical.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              4809.216960   48029                    61
# 1              2228.525238       0                    64
# 2             14947.917300   22139                   100
# 3             22332.439460   49078                    97
# 6              5035.035257   37405                    63
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                      7.0                             52
# 1                      3.0                             26
# 2                     34.0                             31
# 3                     10.0                              3
# 6                      8.0                             99
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                        0.0                   9          292.800000
# 1                        0.0                   1          744.924331
# ...

# %%
categorics = ['object']

categoricals = filtered.select_dtypes(include=categorics).copy()

#I then add it to this dataframe
categoricals['month'] = filtered["month"]
categoricals.head()
# Out:
#   customer       state response  coverage education employmentstatus gender  \
# 0  DK49336     Arizona       No     Basic   College         Employed      M
# 1  KX64629  California       No     Basic   College       Unemployed      F
# 2  LZ68649  Washington       No     Basic  Bachelor         Employed      M
# 3  XL78013      Oregon      Yes  Extended   College         Employed      M
# 6  IW72280  California       No     Basic    Doctor         Employed      F
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer3
# 1      Suburban         Single   Personal Auto   Personal L3           Offer4
# 2      Suburban         Single   Personal Auto   Personal L3           Offer3
# 3      Suburban         Single  Corporate Auto  Corporate L3           Offer2
# 6         Urban        Married  Corporate Auto  Corporate L2           Offer2
#
# ...

# %%
#Now we will try to check the normality of the numerical variables visually
#Use seaborn library to construct distribution plots for the numerical variables

sns.displot(numerical['customer_lifetime_value'], bins=50)
sns.displot(numerical['income'], bins=50)
sns.displot(numerical['monthly_premium_auto'], bins=50)
sns.displot(numerical['months_since_last_claim'], bins=30)
sns.displot(numerical['months_since_policy_inception'], bins=50)
sns.displot(numerical['number_of_open_complaints'], bins=10)
sns.displot(numerical['number_of_policies'], bins=10)
sns.displot(numerical['total_claim_amount'], bins=50)
plt.show()

# %%
#Use Matplotlib to construct histograms
fig, axes = plt.subplots(4, 2)
sns.histplot(data=numerical, x='customer_lifetime_value', ax=axes[0][1])
sns.histplot(data=numerical, x='income', ax=axes[0][0])
sns.histplot(data=numerical, x='monthly_premium_auto', ax=axes[2][0])
sns.histplot(data=numerical, x='months_since_last_claim', ax=axes[3][0])
sns.histplot(data=numerical, x='months_since_policy_inception', ax=axes[1][0])
sns.histplot(data=numerical, x='number_of_open_complaints', ax=axes[1][1])
sns.histplot(data=numerical, x='number_of_policies', ax=axes[2][1])
sns.histplot(data=numerical, x='total_claim_amount', ax=axes[3][1])

plt.tight_layout()
plt.show()
#Do the distributions for different numerical variables look like a normal distribution

#No, some of them look skewed to the right, while others seem to follow different distributions

# %%
#For the numerical variables, check the multicollinearity between the features. Please note that we will use the 
#column total_claim_amount later as the target variable

correlations_matrix = numerical.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.tight_layout()
plt.show()

#It is very hard to read, so in the next cell I will create a correlation matrix with the condition that values smaller than 0.3 are shown as 0.

# %%
import numpy as np
subjective_corr = numerical.corr()
subjective_corr[np.abs(subjective_corr)<.3] = 0
plt.figure(figsize=(7,6))
mask = np.triu(np.ones_like(numerical.corr(), dtype=bool))

sns.heatmap(subjective_corr, annot=True, mask=mask)  ;

# %%
#Drop one of the two features that show a high correlation between them (greater than 0.9).
#Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that 
#have a high correlation, then do not drop any features
subjective_corr = numerical.corr()
display(subjective_corr)
#There are no pair of features with a correlation greater than 0.9
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.024366
# income                                        0.024366  1.000000
# monthly_premium_auto                          0.396262 -0.016665
# months_since_last_claim                       0.011517 -0.026715
# months_since_policy_inception                 0.009418 -0.000875
# number_of_open_complaints                    -0.036343  0.006408
# number_of_policies                            0.021955 -0.008656
# total_claim_amount                            0.226451 -0.355254
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly_premium_auto                       1.000000                 0.005026
# ...

# %%
##Customer Analysis Round 7
# First, I will try to improve the model by getting rid of outliers
iqr = np.percentile(numerical['customer_lifetime_value'],75) - np.percentile(numerical['customer_lifetime_value'],25)
upper_limit = np.percentile(numerical['customer_lifetime_value'],75) + 1.5*iqr 
lower_limit = np.percentile(numerical['customer_lifetime_value'],25) - 1.5*iqr 

numerical0 = numerical[(numerical['customer_lifetime_value']>lower_limit) & (numerical['customer_lifetime_value']<upper_limit)]
sns.boxplot(x=numerical0['customer_lifetime_value'])
plt.show()

# %%
#X-y split.

from sklearn.preprocessing import MinMaxScaler
#Monthly premium auto was the only column which held some level of acceptable correlation with the target variable "total claim amount"
y = numerical0['total_claim_amount']

X = numerical0[['monthly_premium_auto', 'income']].copy()

X =pd.DataFrame(X)

# %%
# This time, we apply a minmax scaler

transformer = MinMaxScaler().fit(X)
x_scaled = transformer.transform(X)
print(x_scaled.shape)



pd.DataFrame(x_scaled, columns=X.columns)
# Out:
# (8317, 2)
#       monthly_premium_auto    income
# 0                 0.000000  0.480381
# 1                 0.012658  0.000000
# 2                 0.164557  0.221432
# 3                 0.008439  0.374121
# 4                 0.008439  0.872136
# ...                    ...       ...
# 8312              0.232068  0.335374
# 8313              0.126582  0.283094
# 8314              0.054852  0.598664
# 8315              0.016878  0.611576
# 8316              0.409283  0.642072
#
# [8317 rows x 2 columns]

# %%
#We had previously set the test_size to 0.2, now we will try with 0.15

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

x_train ,x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.15, random_state=100)
lm = linear_model.LinearRegression()
lm.fit(x_train, y_train)
y_pred_train= lm.predict(x_train)
y_pred_test= lm.predict(x_test)

#Plot to see if there are any big outliers 
fig,ax = plt.subplots()
line   = [y.min(), y.max()]
sns.scatterplot(y=y_pred_train, x=y_train, ax=ax)
z = np.polyfit(y_train, y_pred_train, 1)
p = np.poly1d(z)
plt.plot(y_train,p(y_train),"r--")



print("Mean squared error (train): %.2f" % mean_squared_error(y_train, y_pred_train))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination (train): %.2f" % r2_score(y_train, y_pred_train))

print("Mean absolute error (train): %.2f" % mean_absolute_error(y_train, y_pred_train))


print("Mean squared error (test): %.2f" % mean_squared_error(y_test, y_pred_test))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination (test): %.2f" % r2_score(y_test, y_pred_test))

print("Mean absolute error (test): %.2f" % mean_absolute_error(y_test, y_pred_test))
# Out:
# Mean squared error (train): 38143.07
# Coefficient of determination (train): 0.50
# Mean absolute error (train): 141.67
# Mean squared error (test): 40613.03
# Coefficient of determination (test): 0.47
# Mean absolute error (test): 140.71
